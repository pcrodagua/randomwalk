% %%
V=load('/home/cyborx/GitProys/randomwalk/t58k.dat');

% %%
for i=1 : length(V)
    if V(i,2)>30 && V(i,2)<130 && V(i,1)>49 && V(i,1)<799
        v(i,1)=V(i,1);
        v(i,2)=V(i,2); 
    end
  
end
v( ~any(v,2), : ) = [];  %rows
v( :, ~any(v,1) ) = [];  %columns
plot(v(:,1),v(:,2),'*')

for i=1 : length(v)
    if v(i,1)>=130 && v(i,1)<=169 ||v(i,1)>=250 && v(i,1)<=310 ||v(i,1)>=390 && v(i,1)<=450 ||v(i,1)>=520 && v(i,1)<=580 ||v(i,1)>=650 && v(i,1)<=709
        l=1;
    else
        b(i,1)=v(i,1);
        b(i,2)=v(i,2);
    end
    
  
end
b( ~any(b,2), : ) = [];  %rows
b( :, ~any(b,1) ) = [];  %columns
%length(v);


hist(v)
plot(b(:,1),b(:,2),'*')

save('/home/cyborx/GitProys/randomwalk/DataSinOutlier.mat', 'b');
V=load('/home/cyborx/GitProys/randomwalk/t58k.dat');

for i=1 : length(V)
    if V(i,2)>30 && V(i,2)<130 && V(i,1)>49 && V(i,1)<799
        v(i,1)=V(i,1);
        v(i,2)=V(i,2); 
    end
  
end
v( ~any(v,2), : ) = [];  %rows
v( :, ~any(v,1) ) = [];  %columns
plot(v(:,1),v(:,2),'*')

for i=1 : length(v)
    if v(i,1)>=130 && v(i,1)<=169 ||v(i,1)>=250 && v(i,1)<=310 ||v(i,1)>=390 && v(i,1)<=450 ||v(i,1)>=520 && v(i,1)<=580 ||v(i,1)>=650 && v(i,1)<=709
        l=1;
    else
        b(i,1)=v(i,1);
        b(i,2)=v(i,2);
    end
    
  
end
b( ~any(b,2), : ) = [];  %rows
b( :, ~any(b,1) ) = [];  %columns
%length(v);


hist(v)
plot(b(:,1),b(:,2),'*')

save('DataSinOutlier.mat', 'b');
