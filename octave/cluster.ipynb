% %%
V=load('../t58k.dat');

% %%
plot(V(:,1),V(:,2),'*')

% %%
for i=1:length(V)
    for j=1:length(V)
        dis(i,j)= sqrt((((V(i,1))- (V(j,1)))^2)+ (((V(i,2))- (V(j,2)))^2));
    end 
end

% %%
d=dis;
save('distancias.mat','dis')
